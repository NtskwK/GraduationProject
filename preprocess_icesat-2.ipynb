# %% [markdown]
# # 环境初始化

# %%
import pickle
import pprint

from pathlib import Path

import pandas
import matplotlib
import matplotlib.pyplot as plt

import h5py

# 获取文件所在路径

# 茅尾海

# file = Path(r"E:\Documents\课程学习\GraduationProject\program\data4\309472364\processed_ATL03_20240701164115_02172407_006_01_gt2l.csv")

# file = Path(r"E:\Documents\课程学习\GraduationProject\program\data4\309472364\processed_ATL03_20240701164115_02172407_006_01_gt1l.csv")

# file = Path(r"E:\Documents\课程学习\GraduationProject\program\data4\309459250\processed_ATL03_20240624045213_01032401_006_01_gt3r.csv")

# file = Path(r"E:\Documents\课程学习\GraduationProject\program\data4\309459250\processed_ATL03_20240624045213_01032401_006_01_gt3r.csv")

# file = Path(r"E:\Documents\课程学习\GraduationProject\program\data4\305666442\processed_ATL03_20240102012203_02172207_006_01_gt1r.csv")

# file = Path(r"E:\Documents\课程学习\GraduationProject\program\data4\297965547\processed_ATL03_20231003054219_02172107_006_02_gt2l.csv")

# file = Path(r"E:\Documents\课程学习\GraduationProject\program\data4\297965547\processed_ATL03_20231003054219_02172107_006_02_gt1l.csv")

# file = Path(r"E:\Documents\课程学习\GraduationProject\program\data4\297322458\processed_ATL03_20231225133258_01032201_006_02_gt2r.csv")

# file = Path(r"E:\Documents\课程学习\GraduationProject\program\data\icepyx\2022MaoweiSea\20220427\processed_ATL03_20220427183114_05451501_006_02_gt1l.csv")

# 茅尾海（南）

# 可用
# file = Path(r"E:\Documents\课程学习\GraduationProject\program\data\icepyx\2022MaoweiSea\20221004\processed_ATL03_20221004230400_02171707_006_01_gt1r.csv")

# file = Path(r"E:\Documents\课程学习\GraduationProject\program\data\icepyx\2022MaoweiSea\20221004\processed_ATL03_20221004230400_02171707_006_01_gt2r.csv")

# 陆地
# file = Path(r"E:\Documents\课程学习\GraduationProject\program\data\icepyx\2022MaoweiSeaSouth\20220105\processed_ATL03_20220105120423_02171407_006_01_gt3l.csv")

# 可用
# file = Path(r"E:\Documents\课程学习\GraduationProject\program\data\icepyx\2022MaoweiSeaSouth\20220105\processed_ATL03_20220105120423_02171407_006_01_gt2l.csv")

# file = Path(r"E:\Documents\课程学习\GraduationProject\program\data\icepyx\2022MaoweiSeaSouth\20220105\processed_ATL03_20220105120423_02171407_006_01_gt1l.csv")




# file = "processed_ATL03_20240401210123_02172307_006_01_gt2r.csv"
# data_dir = Path(r"E:\Documents\课程学习\GraduationProject\program\data\306392100")

# file = "processed_ATL03_20231003054219_02172107_006_02_gt1l.csv"
# data_dir = Path(r"E:\Documents\课程学习\GraduationProject\program\data\297965547")

# file = "processed_ATL03_20231225133258_01032201_00ject\prog6_02_gt1l.csv"
# data_dir = Path(r"E:\Documents\课程学习\GraduationProram\data\297322458")

# file = "processed_ATL03_20220213092400_08111406_006_01_gt1l.csv"
# data_dir = Path(r"E:\Documents\课程学习\GraduationProject\program\data\273928961")

# 三娘湾

# file = "processed_ATL03_20240430193724_06592307_006_01_gt3r.csv"
# data_dir = Path(r"E:\Documents\课程学习\GraduationProject\program\data1\306469545")

# file = "processed_ATL03_20240730151657_06592407_006_01_gt3l.csv"
# data_dir = Path(r"E:\Documents\课程学习\GraduationProject\program\data1\309484464")

# file = "processed_ATL03_20230802083845_06592007_006_02_gt1l.csv"
# data_dir = Path(r"E:\Documents\课程学习\GraduationProject\program\data1\297353965")

# file = "processed_ATL03_20230426011031_05451901_006_02_gt3r.csv"
# data_dir = Path(r"E:\Documents\课程学习\GraduationProject\program\data1\296918138")

# 涠洲岛

# file = Path(r"E:\Documents\课程学习\GraduationProject\program\data2\297346650\processed_ATL03_20230823192538_09872001_006_02_gt2l.csv")

# file = Path(r"E:\Documents\课程学习\GraduationProject\program\data2\297346650\processed_ATL03_20230823192538_09872001_006_02_gt1l.csv")

# 可用
file = Path(r"E:\Documents\课程学习\GraduationProject\program\data2\297281164\processed_ATL03_20231122150528_09872101_006_02_gt3l.csv")

# 深圳湾

# file = Path(r"E:\Documents\课程学习\GraduationProject\program\data深圳湾\297327922\processed_ATL03_20231205022026_11772107_006_02_gt3l.csv")

# file = Path(r"E:\Documents\课程学习\GraduationProject\program\data深圳湾\296404088\processed_ATL03_20221228062904_01181801_006_02_gt2l.csv")

# file = Path(r"E:\Documents\课程学习\GraduationProject\program\data深圳湾\297327922\processed_ATL03_20231205022026_11772107_006_02_gt3l.csv")

# file = Path(r"E:\Documents\课程学习\GraduationProject\program\data深圳湾\296404088\processed_ATL03_20221228062904_01181801_006_02_gt1l.csv")

# file = Path(r"E:\Documents\课程学习\GraduationProject\program\data深圳湾\273204920\processed_ATL03_20211201011339_10631301_006_01_gt3l.csv")

# file = Path(r"E:\Documents\课程学习\GraduationProject\program\data深圳湾\273204920\processed_ATL03_20211201011339_10631301_006_01_gt2l.csv")

# file = Path(r"E:\Documents\课程学习\GraduationProject\program\data深圳湾\264404022\processed_ATL03_20210908172247_11771207_006_02_gt3r.csv")


# data_dir = Path("../dataset/")
# data_path = data_dir / "297322458" / "processed_ATL03_20231225133258_01032201_006_02.h5"


# gtx = "/gt1l"; 

# data_path = data_dir / file
# assert data_path.exists()

data_path = file

# data = h5py.File(data_path, 'r')

# %%
# 读取csv文件
with open(data_path, 'r') as f:
    df = pandas.read_csv(f)
    # 打印每列的标题
    print(df.columns)
    # 打印每列的数据类型
    # print(df.dtypes)
    unique_values = df['Classification'].unique()
    print(unique_values)
    print(df['Latitude (deg)'].max())
    print(df['Latitude (deg)'].min())
    # 画图
    # df.plot(x='Latitude (deg)', y='Solar Elevation (deg)', kind='scatter', s=1)
    df.plot(x='Latitude (deg)', y='Height (m MSL)', kind='scatter', s=1)
    # df.plot(x='Latitude (deg)', y='Height (m HAE)', kind='scatter', s=1)
    # plt.xlim(21.725,21.75)
    # plt.xlim(21.75,21.77)
    # plt.xlim(21.77,21.80)
    # plt.xlim(21.785,21.80)
    # plt.xlim(21.80,21.88)
    # plt.xlim(21.82,21.84)
    # plt.xlim(21.80,21.87)
    # plt.xlim(21.82,21.86)
    # plt.xlim(21.82,21.86)
    # plt.xlim(21.590,21.604)
    plt.ylim(-100,100)
    plt.ylim(-50,20)
    plt.ylim(-15,10)
    plt.ylim(-5,5)
    # plt.ylim(-4,2)
    # plt.ylim(-2,4)
    # plt.ylim(-1,2)
    # plt.ylim(0,1.5)
    # plt.ylim(0.5,2.5)
    # plt.ylim(1,2)
    # plt.xlim(21.85,21.89)
    # plt.xlim(21.86,21.885)
    
    # plt.xlim(21.068,21.08)

    # 深圳湾大致范围
    # plt.xlim(22.45,22.53)
    
    # plt.ylim(-4,0)
    # plt.ylim(-140,-120)
    # plt.xlim(21.833,21.88)
    
    # plt.xlim(22.45,22.47)
    # plt.xlim(22.485,22.53)
    
    # plt.xlim(22.455,22.525)
    # plt.ylim(-5,-1)
    # plt.ylim(-132.5,-122.5)
    
    plt.title(data_path.name)
    # plt.savefig(data_path.name[:-4] + ".png")
    plt.show()
# Out:
# Index(['Time (sec)', 'Delta Time (sec)', 'Segment ID', 'GT Num', 'Beam Num',
#        'Beam Type', 'Latitude (deg)', 'Longitude (deg)', 'UTM Easting (m)',
#        'UTM Northing (m)', 'UTM Zone', 'UTM Hemisphere', 'Cross-Track (m)',
#        'Along-Track (m)', 'Height (m HAE)', 'Height (m MSL)', 'Classification',
#        'Signal Confidence', 'Solar Elevation (deg)'],
#       dtype='object')
# [0.]
# 21.110173160740352
# 20.97399110111973
